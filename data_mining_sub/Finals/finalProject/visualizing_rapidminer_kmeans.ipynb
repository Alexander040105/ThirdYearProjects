# %%
import pandas as pd
import os
import numpy as np 
import matplotlib.pyplot as plt

# %%
current_directory = os.getcwd()
df = pd.read_csv(f'{current_directory}\\rapidMinerResults.csv')
df_copy = df.copy()
df.head(1)
# Out:
#     Age  Total_Score  Study_Hours_per_Week  Sleep_Hours_per_Night   id  \
# 0  24.0         70.3                  20.7                    6.2  1.0
#
#      cluster Academic_risk Gender Family_Income_Level
# 0  cluster_0        Medium   Male                 Low
